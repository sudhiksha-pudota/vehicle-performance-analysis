# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv('vehicle_performance.csv')
df.head()
# Out:
#    origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 0       1          8         307.0        130    3504          12.0  1970
# 1       1          8         350.0        165    3693          11.5  1970
# 2       1          8         318.0        150    3436          11.0  1970
# 3       1          8         304.0        150    3433          12.0  1970
# 4       1          8         302.0        140    3449          10.5  1970
#
#                         name  Kilometer_per_liter
# 0  chevrolet chevelle malibu             7.652587
# 1          buick skylark 320             6.377156
# 2         plymouth satellite             7.652587
# 3              amc rebel sst             6.802299
# 4                ford torino             7.227443

# %%
df.shape
# Out:
# (398, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   origin               398 non-null    int64
#  1   cylinders            398 non-null    int64
#  2   displacement         398 non-null    float64
#  3   horsepower           398 non-null    object
#  4   weight               398 non-null    int64
#  5   acceleration         398 non-null    float64
#  6   year                 398 non-null    int64
#  7   name                 398 non-null    object
#  8   Kilometer_per_liter  398 non-null    float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [origin, cylinders, displacement, horsepower, weight, acceleration, year, name, Kilometer_per_liter]
# Index: []

# %%
df.isnull().sum()
# Out:
# origin                 0
# cylinders              0
# displacement           0
# horsepower             0
# weight                 0
# acceleration           0
# year                   0
# name                   0
# Kilometer_per_liter    0
# dtype: int64

# %%
df.horsepower.unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
df[df.horsepower == '?'].shape
# Out:
# (6, 9)

# %%
df.horsepower.replace('?',np.nan, inplace=True)

# %%
df[df.horsepower == '?']
# Out:
# Empty DataFrame
# Columns: [origin, cylinders, displacement, horsepower, weight, acceleration, year, name, Kilometer_per_liter]
# Index: []

# %%
df['horsepower'] = df['horsepower'].astype('float')

# %%
df['horsepower']
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 393     86.0
# 394     52.0
# 395     84.0
# 396     79.0
# 397     82.0
# Name: horsepower, Length: 398, dtype: float64

# %%
df.isnull().sum()
# Out:
# origin                 0
# cylinders              0
# displacement           0
# horsepower             6
# weight                 0
# acceleration           0
# year                   0
# name                   0
# Kilometer_per_liter    0
# dtype: int64

# %%
df.horsepower.fillna(df.horsepower.median(), inplace = True)

# %%
df.horsepower.isnull().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# origin                   int64
# cylinders                int64
# displacement           float64
# horsepower             float64
# weight                   int64
# acceleration           float64
# year                     int64
# name                    object
# Kilometer_per_liter    float64
# dtype: object

# %%
x= df.drop(['name', 'Kilometer_per_liter'], axis=1)
y= df['Kilometer_per_liter']
x
# Out:
#      origin  cylinders  displacement  horsepower  weight  acceleration  year
# 0         1          8         307.0       130.0    3504          12.0  1970
# 1         1          8         350.0       165.0    3693          11.5  1970
# 2         1          8         318.0       150.0    3436          11.0  1970
# 3         1          8         304.0       150.0    3433          12.0  1970
# 4         1          8         302.0       140.0    3449          10.5  1970
# ..      ...        ...           ...         ...     ...           ...   ...
# 393       1          4         140.0        86.0    2790          15.6  1982
# 394       2          4          97.0        52.0    2130          24.6  1982
# 395       1          4         135.0        84.0    2295          11.6  1982
# 396       1          4         120.0        79.0    2625          18.6  1982
# 397       1          4         119.0        82.0    2720          19.4  1982
#
# [398 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, random_state = 42)

# %%
x_train
# Out:
#      origin  cylinders  displacement  horsepower  weight  acceleration  year
# 3         1          8         304.0       150.0    3433          12.0  1970
# 18        3          4          97.0        88.0    2130          14.5  1970
# 376       3          4          91.0        68.0    2025          18.2  1982
# 248       3          4          91.0        60.0    1800          16.4  1978
# 177       2          4         115.0        95.0    2694          15.0  1975
# ..      ...        ...           ...         ...     ...           ...   ...
# 71        3          3          70.0        97.0    2330          13.5  1972
# 106       1          8         350.0       180.0    4499          12.5  1973
# 270       3          4         134.0        95.0    2515          14.8  1978
# 348       3          4          89.0        62.0    2050          17.3  1981
# 102       2          4          97.0        46.0    1950          21.0  1973
#
# [318 rows x 7 columns]

# %%
x_train.shape
# Out:
# (318, 7)

# %%
x_test.shape
# Out:
# (80, 7)

# %%
y_train.shape
# Out:
# (318,)

# %%
y_test.shape
# Out:
# (80,)

# %%
from sklearn.linear_model import SGDRegressor

# %%
model = SGDRegressor()

# %%
model.fit(x_train, y_train)
# Out:
# SGDRegressor()

# %%
train_results = pd.DataFrame()

# %%
train_results['Actual_values'] = y_train

# %%
train_results['Predicted_value']= model.predict(x_train)
train_results
# Out:
#      Actual_values  Predicted_value
# 3         6.802299    -2.735018e+15
# 18       11.478880    -2.716036e+15
# 376      15.730317    -2.678658e+15
# 248      15.347688    -2.565643e+15
# 177       9.778305    -2.923603e+15
# ..             ...              ...
# 71        8.077730    -2.897604e+15
# 106       5.101724    -3.103606e+15
# 270       8.970532    -2.790311e+15
# 348      16.027918    -2.687535e+15
# 102      11.053736    -2.594767e+15
#
# [318 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
sx_train = ss.fit_transform(x_train)

# %%
sx_train= pd.DataFrame(ss.fit_transform(x_train), columns = x_train.columns)
sx_train
# Out:
#        origin  cylinders  displacement  horsepower    weight  acceleration  \
# 0   -0.729494   1.527188      1.090196    1.265821  0.552826     -1.319334
# 1    1.738368  -0.850515     -0.922996   -0.408635 -0.999667     -0.413182
# 2    1.738368  -0.850515     -0.981350   -0.948782 -1.124772      0.927922
# 3    1.738368  -0.850515     -0.981350   -1.164840 -1.392854      0.275493
# 4    0.504437  -0.850515     -0.747936   -0.219583 -0.327675     -0.231952
# ..        ...        ...           ...         ...       ...           ...
# 313  1.738368  -1.444941     -1.185587   -0.165569 -0.761372     -0.775643
# 314 -0.729494   1.527188      1.537573    2.076041  1.822940     -1.138103
# 315  1.738368  -0.850515     -0.563150   -0.219583 -0.540949     -0.304444
# 316  1.738368  -0.850515     -1.000801   -1.110826 -1.094985      0.601707
# 317  0.504437  -0.850515     -0.922996   -1.542943 -1.214133      1.942811
#
#          year
# 0   -1.696667
# 1   -1.696667
# 2    1.638975
# 3    0.527094
# 4   -0.306816
# ..        ...
# 313 -1.140727
# 314 -0.862757
# 315  0.527094
# 316  1.361005
# 317 -0.862757
#
# [318 rows x 7 columns]

# %%
sx_test = pd.DataFrame(ss.transform(x_test), columns = x_test.columns)
sx_test
# Out:
#       origin  cylinders  displacement  horsepower    weight  acceleration  \
# 0   1.738368  -0.850515     -0.981350   -1.353892 -1.398812      0.637953
# 1  -0.729494  -0.850515     -0.699308   -0.651701 -0.409887      1.072906
# 2  -0.729494   0.338337      0.389956   -0.084547 -0.399163     -0.956873
# 3  -0.729494   1.527188      1.226354    1.265821  1.156905     -0.884381
# 4  -0.729494   1.527188      1.226354    1.265821  1.510773     -0.413182
# ..       ...        ...           ...         ...       ...           ...
# 75 -0.729494   1.527188      0.662271    0.185527  0.471806     -0.050722
# 76 -0.729494   0.338337      0.565016    0.185527  0.656485      0.275493
# 77 -0.729494  -0.850515     -0.777113   -0.408635 -0.433716      1.435367
# 78  0.504437  -0.850515     -0.991075   -0.894767 -1.229622     -0.594413
# 79 -0.729494   1.527188      1.099922    0.725674  1.037757     -0.086968
#
#         year
# 0  -0.028846
# 1   1.638975
# 2  -1.418697
# 3  -0.028846
# 4  -0.862757
# ..       ...
# 75  0.527094
# 76  0.249124
# 77  1.638975
# 78 -0.306816
# 79  0.805065
#
# [80 rows x 7 columns]

# %%
import pickle

# %%
with open('scaler.pkl', 'wb') as file:
    pickle.dump(ss, file)

# %%
model1= SGDRegressor()
model1.fit(sx_train, y_train)
# Out:
# SGDRegressor()

# %%
train_result_scaling = pd.DataFrame()

# %%
train_result_scaling['actual']= y_train

# %%
train_result_scaling['predicted'] = model1.predict(sx_train)
train_result_scaling['error'] = train_result_scaling['actual'] - train_result_scaling['predicted']
train_result_scaling
# Out:
#         actual  predicted     error
# 3     6.802299   6.334511  0.467788
# 18   11.478880  10.832864  0.646016
# 376  15.730317  15.136750  0.593568
# 248  15.347688  14.457792  0.889896
# 177   9.778305  10.562734 -0.784429
# ..         ...        ...       ...
# 71    8.077730  10.932311 -2.854580
# 106   5.101724   4.592967  0.508757
# 270   8.970532  12.525498 -3.554966
# 348  16.027918  14.826406  1.201512
# 102  11.053736  11.995783 -0.942046
#
# [318 rows x 3 columns]

# %%
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, r2_score

# %%
mse = mean_squared_error(train_result_scaling['actual'], train_result_scaling['predicted'])
rmse = root_mean_squared_error(train_result_scaling['actual'], train_result_scaling['predicted'])
mae = mean_absolute_error(train_result_scaling['actual'], train_result_scaling['predicted'])
r2 = r2_score(train_result_scaling['actual'], train_result_scaling['predicted'])

# %%
print('Training: ')
print()
print(F'Mean Squared Error = {mse}')
print(F'Root Mean Squared Error = {rmse}')
print(F'Mean Absolute Error = {mae}')
print(F'R2 = {r2}')
# Out:
# Training:
#
# Mean Squared Error = 2.1344194935538696
# Root Mean Squared Error = 1.4609652608990638
# Mean Absolute Error = 1.1046965304422178
# R2 = 0.81164944987152

# %%
test_result_scaling = pd.DataFrame()

# %%
test_result_scaling['actual'] = y_test
test_result_scaling['predicted'] = model1.predict(sx_test)
test_result_scaling
# Out:
#         actual  predicted
# 198  14.029742  13.867778
# 396  11.904024  12.571944
# 33    8.077730   8.932399
# 208   5.526868   7.124126
# 93    5.952012   5.434729
# ..         ...        ...
# 249   8.460360   9.412865
# 225   7.440015   8.712842
# 367  11.904024  12.501424
# 175  12.329168  12.553373
# 285   7.227443   8.488633
#
# [80 rows x 2 columns]

# %%
mse_test = mean_squared_error(test_result_scaling['actual'], test_result_scaling['predicted'])
rmse_test = root_mean_squared_error(test_result_scaling['actual'], test_result_scaling['predicted'])
mae_test = mean_absolute_error(test_result_scaling['actual'], test_result_scaling['predicted'])
r2_test = r2_score(test_result_scaling['actual'], test_result_scaling['predicted'])

# %%
print('Testing: ')
print()
print(F'Mean Squared Error = {mse_test}')
print(F'Root Mean Squared Error = {rmse_test}')
print(F'Mean Absolute Error = {mae_test}')
print(F'R2 = {r2_test}')
# Out:
# Testing:
#
# Mean Squared Error = 1.5495348784174157
# Root Mean Squared Error = 1.2448031484605973
# Mean Absolute Error = 0.9716174833836095
# R2 = 0.8405521993271514

# %%
from sklearn.model_selection import cross_val_score

# %%
scores_train = cross_val_score(model1, sx_train, y_train, cv=5, scoring = "r2")
scores_train
# Out:
# array([0.83360106, 0.78736584, 0.81883688, 0.77486564, 0.77883659])

# %%
np.mean(scores_train)
# Out:
# np.float64(0.798701201829498)

# %%
scores_test = cross_val_score(model1, sx_test, y_test, cv=5, scoring = "r2")
scores_test
# Out:
# array([0.91043604, 0.67385435, 0.82690119, 0.87586562, 0.81900668])

# %%
np.mean(scores_test)
# Out:
# np.float64(0.8212127774449447)

# %%
training_accuracy = model1.score(sx_train, y_train)
testing_accuracy = model1.score(sx_test, y_test)
print(F'Training Accuracy = {training_accuracy}')
print(F'Testing Accuracy = {testing_accuracy}')
# Out:
# Training Accuracy = 0.81164944987152
# Testing Accuracy = 0.8405521993271514

# %% [markdown]
# ANN Implementation

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
import datetime

# %%
model = Sequential([
    Dense(64, activation = 'relu', input_shape = (x_train.shape[1],)), ## HL1
    Dense(32, activation = 'relu'), ## HL2
    Dense(1), ## Output layer
]
)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,625 (10.25 KB)
#  Trainable params: 2,625 (10.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow
opt = tensorflow.keras.optimizers.Adam(learning_rate = 0.01)
loss = tensorflow.keras.losses.MeanSquaredError()
loss
# Out:
# <LossFunctionWrapper(<function mean_squared_error at 0x00000151AE6C7100>, kwargs={})>

# %%
model.compile(optimizer = opt, loss = "mean_squared_error", metrics = ['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
## Set up Early Stopping

early_stopping_callbacks = EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)

# %%
## Train the model
history = model.fit(
    sx_train, y_train, validation_data = (sx_test, y_test), epochs = 100,
    callbacks = [early_stopping_callbacks]
)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.0000e+00 - loss: 64.0920 - val_accuracy: 0.0000e+00 - val_loss: 12.8123
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 13.9735 - val_accuracy: 0.0000e+00 - val_loss: 5.3117
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0000e+00 - loss: 7.4303 - val_accuracy: 0.0000e+00 - val_loss: 4.1109
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 4.4125 - val_accuracy: 0.0000e+00 - val_loss: 3.1277
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0000e+00 - loss: 3.1775 - val_accuracy: 0.0000e+00 - val_loss: 2.0139
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 2.7070 - val_accuracy: 0.0000e+00 - val_loss: 2.0517
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 2.3290 - val_accuracy: 0.0000e+00 - val_loss: 1.6664
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 2.3737 - val_accuracy: 0.0000e+00 - val_loss: 1.3401
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 2.2155 - val_accuracy: 0.0000e+00 - val_loss: 1.4860
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.0000e+00 - loss: 2.0410 - val_accuracy: 0.0000e+00 - val_loss: 1.2857
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.9108 - val_accuracy: 0.0000e+00 - val_loss: 1.4829
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.8428 - val_accuracy: 0.0000e+00 - val_loss: 1.1323
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.7716 - val_accuracy: 0.0000e+00 - val_loss: 1.1245
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 1.6804 - val_accuracy: 0.0000e+00 - val_loss: 1.2368
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 1.6110 - val_accuracy: 0.0000e+00 - val_loss: 1.0330
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 1.5940 - val_accuracy: 0.0000e+00 - val_loss: 1.0402
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 1.5994 - val_accuracy: 0.0000e+00 - val_loss: 1.0467
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0000e+00 - loss: 1.5601 - val_accuracy: 0.0000e+00 - val_loss: 1.0864
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 1.4848 - val_accuracy: 0.0000e+00 - val_loss: 0.9244
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 1.4198 - val_accuracy: 0.0000e+00 - val_loss: 0.9819
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 1.4174 - val_accuracy: 0.0000e+00 - val_loss: 1.0847
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 1.3953 - val_accuracy: 0.0000e+00 - val_loss: 1.2240
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0000e+00 - loss: 1.5898 - val_accuracy: 0.0000e+00 - val_loss: 0.9727
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0000e+00 - loss: 1.4805 - val_accuracy: 0.0000e+00 - val_loss: 1.0820
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0000e+00 - loss: 1.4614 - val_accuracy: 0.0000e+00 - val_loss: 1.0272
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 1.3288 - val_accuracy: 0.0000e+00 - val_loss: 1.0058
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 1.2878 - val_accuracy: 0.0000e+00 - val_loss: 0.9403
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 1.3121 - val_accuracy: 0.0000e+00 - val_loss: 0.9046
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 1.3420 - val_accuracy: 0.0000e+00 - val_loss: 0.9420
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 1.2794 - val_accuracy: 0.0000e+00 - val_loss: 0.9501
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 1.2691 - val_accuracy: 0.0000e+00 - val_loss: 0.9539
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.2786 - val_accuracy: 0.0000e+00 - val_loss: 0.9739
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 1.3240 - val_accuracy: 0.0000e+00 - val_loss: 0.9186
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 1.2686 - val_accuracy: 0.0000e+00 - val_loss: 1.1357
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 1.4913 - val_accuracy: 0.0000e+00 - val_loss: 1.2445
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0000e+00 - loss: 1.5068 - val_accuracy: 0.0000e+00 - val_loss: 1.4361
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 1.3818 - val_accuracy: 0.0000e+00 - val_loss: 0.9059
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 1.3504 - val_accuracy: 0.0000e+00 - val_loss: 0.9988

# %%
model.save('vehicle_model.keras')
